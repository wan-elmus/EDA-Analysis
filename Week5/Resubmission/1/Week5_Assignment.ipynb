# %%
import pandas as pd
import pickle
from IPython.display import Code
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("churn_data.csv")
df.tail(5)
# Out:
#       customerID  tenure PhoneService        Contract  \
# 7038  6840-RESVB      24          Yes        One year
# 7039  2234-XADUH      72          Yes        One year
# 7040  4801-JZAZL      11           No  Month-to-month
# 7041  8361-LTMKD       4          Yes  Month-to-month
# 7042  3186-AJIEK      66          Yes        Two year
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# 7038               Mailed check           84.80       1990.50    No
# 7039    Credit card (automatic)          103.20       7362.90    No
# 7040           Electronic check           29.60        346.45    No
# 7041               Mailed check           74.40        306.60   Yes
# 7042  Bank transfer (automatic)          105.65       6844.50    No

# %% [markdown]
# ## autoML Environment

# %%
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_36b9e_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_36b9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36b9e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_36b9e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36b9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36b9e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_36b9e_row0_col1" class="data row0 col1" >4858</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36b9e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_36b9e_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36b9e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_36b9e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36b9e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_36b9e_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36b9e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_36b9e_row4_col1" class="data row4 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_36b9e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_36b9e_row5_col1" class="data row5 col1" >(7043, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_36b9e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_36b9e_row6_col1" class="data row6 col1" >(4930, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_36b9e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_36b9e_row7_col1" class="data row7 col1" >(2113, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_36b9e_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_36b9e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_36b9e_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_36b9e_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_36b9e_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_36b9e_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_36b9e_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_36b9e_row11_col1" class="data row11 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_36b9e_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_36b9e_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_36b9e_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_36b9e_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_36b9e_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_36b9e_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_36b9e_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_36b9e_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_36b9e_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_36b9e_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_36b9e_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_36b9e_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_36b9e_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_36b9e_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_36b9e_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_36b9e_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_36b9e_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_36b9e_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_36b9e_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_36b9e_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_36b9e_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_36b9e_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_36b9e_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_36b9e_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_36b9e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_36b9e_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_36b9e_row24_col1" class="data row24 col1" >71ea</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This output summarizes the setup information for the PyCaret auto ML environment designed for the binary classification task predicting `Churn`.
#
# The key points include,
#
# The session has an ID of 4858, and the target variable is Churn, categorized as binary. The original dataset has dimensions (7043, 8), and after transformation, it maintains the same shape. The transformed training set comprises 4930 samples, while the transformed test set has 2113 samples. There are 10 numeric features in the dataset, and the percentage of rows with missing values is 0.2%.
#
# The data has undergone preprocessing with simple imputation. Numeric features have been imputed with the mean, and categorical features with the mode. The cross-validation is performed using StratifiedKFold with 10 folds. The setup utilizes all available CPUs (-1 CPU jobs) and does not employ GPU acceleration. Logging of the experiment is turned off, and the experiment is named `clf-default-name` with a unique session identifier (USI) of 71ea.
#
# The dataset is well-prepared, and the setup is ready for model comparison and selection.

# %% [markdown]
# ## automl setup obhect elements

# %%
automl_element = automl.get_config("X_train")
automl_element
# Out:
#       customerID  tenure PhoneService        Contract  \
# 5348  9495-REDIY      25           No        One year
# 2441  9050-IKDZA       2          Yes  Month-to-month
# 2673  8429-XIBUM      22          Yes  Month-to-month
# 956   3261-CQXOL      71          Yes        Two year
# 5410  4049-ZPALD      64          Yes        Two year
# ...          ...     ...          ...             ...
# 2862  5027-QPKTE       7          Yes  Month-to-month
# 76    6416-JNVRK      46          Yes        One year
# 1020  1452-XRSJV      39          Yes  Month-to-month
# 4992  7740-KKCXF      51           No  Month-to-month
# 3796  8614-VGMMV      15          Yes  Month-to-month
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 5348    Credit card (automatic)       40.650002    970.549988
# 2441               Mailed check       81.500000    162.550003
# 2673  Bank transfer (automatic)      101.349998   2317.100098
# 956   Bank transfer (automatic)       25.450001   1813.349976
# 5410  Bank transfer (automatic)       99.000000   6375.799805
# ...                         ...             ...           ...
# 2862           Electronic check       69.349998    451.100006
# 76      Credit card (automatic)       55.650002   2688.850098
# 1020    Credit card (automatic)       51.049999   2066.000000
# 4992    Credit card (automatic)       30.049999   1529.449951
# 3796           Electronic check       49.099998    679.549988
#
# [4930 rows x 7 columns]

# %% [markdown]
# ## compare classification models

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T